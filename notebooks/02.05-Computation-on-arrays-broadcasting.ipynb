# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="figures/PDSH-cover-small.png">
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*

# %% [markdown]
# <!--NAVIGATION-->
# < [Aggregations: Min, Max, and Everything In Between](02.04-Computation-on-arrays-aggregates.ipynb) | [Contents](Index.ipynb) | [Comparisons, Masks, and Boolean Logic](02.06-Boolean-Arrays-and-Masks.ipynb) >

# %% [markdown]
# # Computation on Arrays: Broadcasting

# %% [markdown]
# We saw in the previous section how NumPy's universal functions can be used to *vectorize* operations and thereby remove slow Python loops.
#
# 向量话的计算
#
# Another means of vectorizing operations is to use NumPy's *broadcasting* functionality.
#
# Broadcasting is simply a set of rules for applying binary ufuncs (e.g., addition, subtraction, multiplication, etc.)
# on arrays of different sizes.

# %% [markdown]
# ## Introducing Broadcasting
#
# Recall that for arrays of the same size, binary operations are performed on an element-by-element basis:

# %%
import numpy as np

# %%
a = np.array([0, 1, 2])
b = np.array([5, 5, 5])
a + b  # ufunc计算
# Out:
# array([5, 6, 7])

# %% [markdown]
# Broadcasting allows these types of binary operations to be performed on arrays of different sizes–for example,
#
# 向量计算的2个对象可以不是相同的数组
#
# we can just as easily add a scalar (标量)(think of it as a zero-dimensional array) to an array:
#
# 向量 + 标量

# %%
a + 5
# Out:
# array([5, 6, 7])

# %% [markdown]
# We can think of this as an operation that stretches or duplicates the value ``5`` into the array ``[5, 5, 5]``, and adds the results.
#
# 理解为对值进行扩张/重复在相加
#
# The advantage of NumPy's broadcasting is that this duplication of values does not actually take place, but it is a useful mental model(理解模型) as we think about broadcasting.
#
# 这只是一种理解模型, 但实际计算过程中并不是这样,
#
#
# We can similarly extend this to arrays of higher dimension. Observe the result when we add a one-dimensional array to a two-dimensional array:

# %%
M = np.ones((3, 3))
M
# Out:
# array([[ 1.,  1.,  1.],
#        [ 1.,  1.,  1.],
#        [ 1.,  1.,  1.]])

# %%
M + a
# Out:
# array([[ 1.,  2.,  3.],
#        [ 1.,  2.,  3.],
#        [ 1.,  2.,  3.]])

# %% [markdown]
# Here the one-dimensional array ``a`` is stretched, or broadcast across the second dimension in order to match the shape of ``M``.
#
# While these examples are relatively easy to understand, more complicated cases can involve broadcasting of both arrays.
#
# Consider the following example:

# %%
a = np.arange(3)
b = np.arange(3)[:, np.newaxis] # 两个参数同时广播的意思

print(a)
print(b)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# Just as before we stretched or broadcasted one value to match the shape of the other, here we've stretched *both* ``a`` and ``b`` to match a common shape, and the result is a two-dimensional array!
# The geometry of these examples is visualized in the following figure (Code to produce this plot can be found in the [appendix](06.00-Figure-Code.ipynb#Broadcasting), and is adapted from source published in the [astroML](http://astroml.org) documentation. Used by permission).

# %% [markdown]
# ![Broadcasting Visual](figures/02.05-broadcasting.png)

# %% [markdown]
# The light boxes represent the broadcasted values: again, this extra memory is not actually allocated in the course of the operation,
#
# but it can be useful conceptually to imagine that it is.
#
# 这是广播计算的过程,实际计算过程中, 并没有多分配内存,只是概念上去假设

# %% [markdown]
# ## Rules of Broadcasting, 扩展的规则是根据shape
#
# Broadcasting in NumPy follows a strict set of rules to determine the interaction between the two arrays:
#
# - Rule 1: If the two arrays differ in their number of dimensions, the shape of the one with fewer dimensions is *padded* with ones on its leading (left) side. 如果参数维度不同,小维度的那个会在左边补1
# - Rule 2: If the shape of the two arrays does not match in any dimension, the array with shape equal to 1 in that dimension is stretched to match the other shape.如果2个数组在任何维度上都不一致,数组的形状会沿着维度为1的方向扩张
# - Rule 3: If in any dimension the sizes disagree and neither is equal to 1, an error is raised.
#     如果两个数组任何维度都补匹配, 且没有维度等于1, 就会报错
#
# To make these rules clear, let's consider a few examples in detail.

# %% [markdown]
# ### Broadcasting example 1
#
# Let's look at adding a two-dimensional array to a one-dimensional array:

# %%
M = np.ones((2, 3))
a = np.arange(3)

# %% [markdown]
# Let's consider an operation on these two arrays. The shape of the arrays are,维度不一致
#
# - ``M.shape = (2, 3)``
# - ``a.shape = (3,)``
#
# We see by rule 1 that the array ``a`` has fewer dimensions, so we pad it on the left with ones:,维度小的左边补1
#
# - ``M.shape -> (2, 3)``
# - ``a.shape -> (1, 3)``
#
# By rule 2, we now see that the first dimension disagrees, so we stretch this dimension to match:沿着维度=1的方向扩展
#
# - ``M.shape -> (2, 3)``
# - ``a.shape -> (2, 3)``
#
# The shapes match, and we see that the final shape will be ``(2, 3)``:

# %%
M + a
# Out:
# array([[ 1.,  2.,  3.],
#        [ 1.,  2.,  3.]])

# %% [markdown]
# ### Broadcasting example 2
#
# Let's take a look at an example where both arrays need to be broadcast:

# %%
a = np.arange(3).reshape((3, 1))
b = np.arange(3)
a
# Out:
# array([[0],
#        [1],
#        [2]])

# %% [markdown]
# Again, we'll start by writing out the shape of the arrays:
#
# - ``a.shape = (3, 1)``
# - ``b.shape = (3,)``
#
# Rule 1 says we must pad the shape of ``b`` with ones:
#
# - ``a.shape -> (3, 1)``
# - ``b.shape -> (1, 3)``
#
# And rule 2 tells us that we upgrade each of these ones to match the corresponding size of the other array:
#
# - ``a.shape -> (3, 3)``
# - ``b.shape -> (3, 3)``
#
# Because the result matches, these shapes are compatible. We can see this here:

# %%
a + b
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %% [markdown]
# ### Broadcasting example 3
#
# Now let's take a look at an example in which the two arrays are not compatible:不能兼容的数组

# %%
M = np.ones((3, 2))
a = np.arange(3)
a[:,np.newaxis].shape
# Out:
# (3, 1)

# %% [markdown]
# This is just a slightly different situation than in the first example:
# the matrix ``M`` is transposed. 转置
# How does this affect the calculation? The shape of the arrays are
#
# - ``M.shape = (3, 2)``
# - ``a.shape = (3,)``
#
# Again, rule 1 tells us that we must pad the shape of ``a`` with ones:
#
# - ``M.shape -> (3, 2)``
# - ``a.shape -> (1, 3)``
#
# By rule 2, the first dimension of ``a`` is stretched to match that of ``M``: 按维度为1的方向没法扩张
#
# - ``M.shape -> (3, 2)``
# - ``a.shape -> (3, 3)``
#
# Now we hit rule 3–the final shapes do not match, so these two arrays are incompatible, as we can observe by attempting this operation:

# %%
M + a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-8cac1d547906> in <module>()
# ----> 1 M + a
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,1)

# %% [markdown]
# Note the potential confusion here: you could imagine making ``a`` and ``M`` compatible by, say, padding ``a``'s shape with ones on the right rather than the left., a数组在left加1而不是在右边
#
# But this is not how the broadcasting rules work!  广播计算没有这样的计算规则
#
# That sort of flexibility might be useful in some cases, but it would lead to potential areas of ambiguity.
# If right-side padding is what you'd like, you can do this explicitly by reshaping the array (we'll use the ``np.newaxis`` keyword introduced in [The Basics of NumPy Arrays](02.02-The-Basics-Of-NumPy-Arrays.ipynb)):

# %%
a[:, np.newaxis].shape
#a.shape
# Out:
# (3, 1)

# %%
M + a[:, np.newaxis]
# Out:
# array([[ 1.,  1.],
#        [ 2.,  2.],
#        [ 3.,  3.]])

# %% [markdown]
# Also note that while we've been focusing on the ``+`` operator here, these broadcasting rules apply to *any* binary ``ufunc``. 广播计算规则适合通用计算的规则
#
#
# For example, here is the ``logaddexp(a, b)`` function, which computes ``log(exp(a) + exp(b))`` with more precision than the naive approach:

# %%
np.logaddexp(M, a[:, np.newaxis])  # logaddexp 是通用函数, 参数的时间使用广播规则
# Out:
# array([[ 1.31326169,  1.31326169],
#        [ 1.69314718,  1.69314718],
#        [ 2.31326169,  2.31326169]])

# %% [markdown]
# For more information on the many available universal functions, refer to [Computation on NumPy Arrays: Universal Functions](02.03-Computation-on-arrays-ufuncs.ipynb).

# %% [markdown]
# ## Broadcasting in Practice

# %% [markdown]
# Broadcasting operations form the core of many examples we'll see throughout this book.
# We'll now take a look at a couple simple examples of where they can be useful.

# %% [markdown]
# ### Centering an array, 数组的归一化

# %% [markdown]
# In the previous section, we saw that ufuncs allow a NumPy user to remove the need to explicitly write slow Python loops. Broadcasting extends this ability. 提高了计算的速度
#
# One commonly seen example is when centering an array of data. 数组的归一话
# Imagine you have an array of 10 observations, each of which consists of 3 values.
#
#
# Using the standard convention (see [Data Representation in Scikit-Learn](05.02-Introducing-Scikit-Learn.ipynb#Data-Representation-in-Scikit-Learn)), we'll store this in a $10 \times 3$ array:

# %%
X = np.random.random((10, 3))
np.random.random?

# %% [markdown]
# We can compute the mean of each feature using the ``mean`` aggregate across the first dimension:

# %%
Xmean = X.mean(0)  # 默认是轴线0
Xmean
# Out:
# array([ 0.54244439,  0.66665346,  0.41107224])

# %% [markdown]
# And now we can center the ``X`` array by subtracting the mean (this is a broadcasting operation):

# %%
X_centered = X - Xmean
X_centered
# Out:
# array([[ 0.3321897 , -0.05221246, -0.26681887],
#        [-0.39060262,  0.12498045,  0.23511628],
#        [ 0.07008654, -0.37179758, -0.07475835],
#        [ 0.2182222 ,  0.08640193, -0.02136441],
#        [ 0.41860679,  0.05011534, -0.07820461],
#        [-0.11530978,  0.20951602,  0.15678252],
#        [-0.54033765,  0.13178102, -0.14562058],
#        [-0.01211536,  0.2766635 , -0.2971777 ],
#        [-0.29459795, -0.39886961,  0.53999529],
#        [ 0.31385812, -0.05657861, -0.04794956]])

# %% [markdown]
# To double-check that we've done this correctly, we can check that the centered array has near zero mean:

# %%
X_centered.mean(0)
# Out:
# array([  2.22044605e-17,  -7.77156117e-17,  -1.66533454e-17])

# %% [markdown]
# To within machine precision, the mean is now zero.

# %% [markdown]
# ### Plotting a two-dimensional function, 画一个二维函数

# %% [markdown]
# One place that broadcasting is very useful is in displaying images based on two-dimensional functions.
#
# 广播对于画二维函数的图像有用
#
# If we want to define a function $z = f(x, y)$, broadcasting can be used to compute the function across the grid:

# %%
# x and y have 50 steps from 0 to 5
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 50)[:, np.newaxis]

z = np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %% [markdown]
# We'll use Matplotlib to plot this two-dimensional array (these tools will be discussed in full in [Density and Contour Plots](04.04-Density-and-Contour-Plots.ipynb)):

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(x,z)   # 二维函数的

# %%
plt.imshow(z, origin='lower', extent=[0, 5, 0, 5],
           cmap='viridis')
plt.colorbar();

# %% [markdown]
# The result is a compelling visualization of the two-dimensional function.

# %% [markdown]
# <!--NAVIGATION-->
# < [Aggregations: Min, Max, and Everything In Between](02.04-Computation-on-arrays-aggregates.ipynb) | [Contents](Index.ipynb) | [Comparisons, Masks, and Boolean Logic](02.06-Boolean-Arrays-and-Masks.ipynb) >
